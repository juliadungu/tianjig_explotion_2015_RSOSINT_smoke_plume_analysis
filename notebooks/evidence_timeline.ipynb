# %% [markdown]
# # Tianjin explosion evidence timeline
# This notebook loads the repository's selected evidence and presents the chronology without inferring a continuous plume trajectory across the overnight gap.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path('..')
timeline = pd.read_csv(ROOT / 'data/event_timeline.csv')
timeline[['event_id','date','utc_time','evidence_type','satellite_or_source','description']]

# %% [markdown]
# ## Interpretation boundary
# H1–H3 are shortwave-infrared observations from 12 August. N1–N2 are MODIS natural-color observations from the following morning. The temporal gap is explicit; the notebook does not interpolate plume position across it.

# %%
selected = pd.read_csv(ROOT / 'data/selected_frames.csv')
selected
